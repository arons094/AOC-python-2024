# %% [markdown]
# --- Day 6: Guard Gallivant ---
#
# The Historians use their fancy device again, this time to whisk you all away to the North Pole prototype suit manufacturing lab... in the year 1518! It turns out that having direct access to history is very convenient for a group of historians.
#
# You still have to be careful of time paradoxes, and so it will be important to avoid anyone from 1518 while The Historians search for the Chief. Unfortunately, a single guard is patrolling this part of the lab.
#
# Maybe you can work out where the guard will go ahead of time so that The Historians can search safely?
#
# You start by making a map (your puzzle input) of the situation. For example:
#
# ```
# ....#.....
# .........#
# ..........
# ..#.......
# .......#..
# ..........
# .#..^.....
# ........#.
# #.........
# ......#...
# ```
#
# The map shows the current position of the guard with ^ (to indicate the guard is currently facing up from the perspective of the map). Any obstructions - crates, desks, alchemical reactors, etc. - are shown as #.
#
# Lab guards in 1518 follow a very strict patrol protocol which involves repeatedly following these steps:
#
# If there is something directly in front of you, turn right 90 degrees.
# Otherwise, take a step forward.
# Following the above protocol, the guard moves up several times until she reaches an obstacle (in this case, a pile of failed suit prototypes):
#
# ```
# ....#.....
# ....^....#
# ..........
# ..#.......
# .......#..
# ..........
# .#........
# ........#.
# #.........
# ......#...
# ```
#
# Because there is now an obstacle in front of the guard, she turns right before continuing straight in her new facing direction:
#
# ```
# ....#.....
# ........>#
# ..........
# ..#.......
# .......#..
# ..........
# .#........
# ........#.
# #.........
# ......#...
# ```
#
# Reaching another obstacle (a spool of several very long polymers), she turns right again and continues downward:
#
# ```
# ....#.....
# .........#
# ..........
# ..#.......
# .......#..
# ..........
# .#......v.
# ........#.
# #.........
# ......#...
# ```
#
# This process continues for a while, but the guard eventually leaves the mapped area (after walking past a tank of universal solvent):
#
# ```
# ....#.....
# .........#
# ..........
# ..#.......
# .......#..
# ..........
# .#........
# ........#.
# #.........
# ......#v..
# ```
#
# By predicting the guard's route, you can determine which specific positions in the lab will be in the patrol path. Including the guard's starting position, the positions visited by the guard before leaving the area are marked with an X:
#
# ```
# ....#.....
# ....XXXXX#
# ....X...X.
# ..#.X...X.
# ..XXXXX#X.
# ..X.X.X.X.
# .#XXXXXXX.
# .XXXXXXX#.
# #XXXXXXX..
# ......#X..
# ```
#
# In this example, the guard will visit 41 distinct positions on your map.
#
# Predict the path of the guard. How many distinct positions will the guard visit before leaving the mapped area?

# %%
import numpy as np

file_path = 'input6.txt'
with open(file_path, 'r') as file:
    lines = [[char for char in line.strip()] for line in file if line.strip()]
    
guard_path = []
grid = np.array(lines)
start_point = np.where(grid == '^')

def move_guard(direction, cur_pos):
    if direction == '^':
        next_pos = (cur_pos[0] - 1, cur_pos[1])
    elif direction == 'v':
        next_pos = (cur_pos[0] + 1, cur_pos[1])
    elif direction == '<':
        next_pos = (cur_pos[0], cur_pos[1] - 1)
    elif direction == '>':
        next_pos = (cur_pos[0], cur_pos[1] + 1)
    else:
        print(f"Error in direction : {direction}")
    return next_pos

cur_pos = (start_point[0][0], start_point[1][0])
next_pos = cur_pos
direction = grid[cur_pos[0]][cur_pos[1]]
path = []
path.append((cur_pos, direction))
while cur_pos[0] < len(grid) and cur_pos[0] >= 0 and cur_pos[1] < len(grid[0]) and cur_pos[1] >= 0:
    next_pos = move_guard(direction, cur_pos)
    if next_pos[0] < 0 or next_pos[0] >= len(grid) or next_pos[1] < 0 or next_pos[1] >= len(grid[0]):
        break
    if grid[next_pos[0]][next_pos[1]] == '#':
        if direction == '^':
            direction = '>'
        elif direction == '>':
            direction = 'v'
        elif direction == 'v':
            direction = '<'
        elif direction == '<':
            direction = '^'
        else:
            print('Error: None of the directions')
        next_pos = move_guard(direction, cur_pos)
        if next_pos[0] < 0 or next_pos[0] >= len(grid) or next_pos[1] < 0 or next_pos[1] >= len(grid[0]):
            break
    cur_pos = next_pos
    path.append((next_pos, direction))


ans1 = len(set([pos for pos, direction in path]))
print(f"Part 1 Answer: {ans1}")
# Out:
# Part 1 Answer: 4826

# %%
def gaurd_path(grid, start, start_direction, )

# %%
og_grid = grid.copy()
cause_loop = set()
for spot in empty_spots:
    grid = og_grid.copy()
    obs = spot
    cur_pos = (start_point[0][0], start_point[1][0])
    next_pos = cur_pos
    direction = grid[cur_pos[0]][cur_pos[1]]
    path = set()
    path.add((cur_pos, direction))
    while cur_pos[0] < len(grid) and cur_pos[0] >= 0 and cur_pos[1] < len(grid[0]) and cur_pos[1] >= 0:
        next_pos = move_guard(direction, cur_pos)
        if next_pos[0] < 0 or next_pos[0] >= len(grid) or next_pos[1] < 0 or next_pos[1] >= len(grid[0]):
            break
        if (grid[next_pos[0]][next_pos[1]] == '#') or (next_pos == obs):
            if direction == '^':
                direction = '>'
            elif direction == '>':
                direction = 'v'
            elif direction == 'v':
                direction = '<'
            elif direction == '<':
                direction = '^'
            else:
                print('Error: None of the directions')
            next_pos = move_guard(direction, cur_pos)
            if next_pos[0] < 0 or next_pos[0] >= len(grid) or next_pos[1] < 0 or next_pos[1] >= len(grid[0]):
                break
        cur_pos = next_pos
        #grid[cur_pos[0]][cur_pos[1]] = 'X'
        if (cur_pos, direction) in path:
            cause_loop.add((spot[0], spot[1]))
            break
        path.add((next_pos, direction))

# %%
cause_loop
# Out:
# {(79, 33),
#  (70, 64),
#  (98, 46),
#  (89, 77),
#  (55, 84),
#  (100, 92),
#  (112, 66),
#  (17, 94),
#  (49, 126),
#  (29, 68),
#  (81, 78),
#  (44, 47),
#  (45, 12),
#  (62, 101),
#  (38, 9),
#  (97, 58),
#  (70, 41),
#  (96, 99),
#  (34, 124),
#  (16, 106),
#  (63, 38),
#  (92, 101),
#  (52, 28),
#  (81, 91),
#  (74, 52),
#  (93, 65),
#  (85, 61),
#  (103, 115),
#  (96, 76),
#  (66, 84),
#  (67, 49),
#  (70, 54),
#  (82, 28),
#  (92, 78),
#  (105, 17),
#  (49, 116),
#  (81, 68),
#  (54, 51),
#  (95, 88),
#  (86, 39),
#  (32, 68),
#  (4, 86),
#  (96, 89),
#  (87, 120),
#  (88, 85),
#  (38, 84),
#  (112, 33),
#  (49, 93),
#  (115, 38),
#  (61, 67),
#  (60, 22),
#  (30, 79),
#  (71, 117),
#  (50, 94),
#  (61, 103),
#  (94, 100),
#  (74, 42),
#  (60, 107),
#  (85, 51),
#  (86, 16),
#  (84, 92),
#  (95, 101),
#  (96, 66),
#  (67, 39),
#  (100, 72),
#  (112, 46),
#  (104, 42),
#  (69, 84),
#  (81, 58),
#  (54, 41),
#  (32, 22),
#  (63, 126),
#  (107, 52),
#  (67, 16),
#  (78, 25),
# ...

# %%
len(cause_loop)
# Out:
# 1732

# %%
for state in path:
    grid[state[0][0]][state[0][1]] = state[1]

for line in grid:
    print(line)
# Out:
# ['.' '.' '.' '.' '#' '.' '.' '.' '.' '.']
# ['.' '.' '.' '.' '^' '>' '>' '>' '>' '#']
# ['.' '.' '.' '.' '^' '.' '.' '.' 'v' '.']
# ['.' '.' '#' '.' '^' '.' '.' '.' 'v' '.']
# ['.' '.' '.' '.' '^' '.' '.' '#' 'v' '.']
# ['.' '.' '.' '.' '^' '.' '.' '.' 'v' '.']
# ['.' '#' '.' '#' '<' '<' '<' '<' 'v' '.']
# ['.' '.' '.' '.' '.' '.' '.' '.' '#' '.']
# ['#' '.' '.' '.' '.' '.' '.' '.' '.' '.']
# ['.' '.' '.' '.' '.' '.' '#' '.' '.' '.']

# %%
locs = [loc for loc, _ in path]
print (len(set(locs)))
# Out:
# 41

# %%
grid = open('input6.txt','r').read().splitlines()

rn, cn = len(grid), len(grid[0])

def get_element(pos):
    r, c = int(pos.real), int(pos.imag)
    if not (0<=r<rn and 0<=c<cn):
        raise IndexError
    return grid[r][c]

def escape_route(grid, pos, direction, obs=None, return_path=False):
    path, vectors = set(), set()

    while True:
        if (vector:=(pos, direction)) in vectors:
            return -1

        vectors.add(vector)
        path.add(pos)

        try:
            if get_element(next_pos:=pos+direction) == '#' or next_pos == obs:
                direction *= -1j
            else:
                pos = next_pos
        except IndexError:
            return path if return_path else len(path)

start_position = next(r+c*1j for r in range(rn) for c in range(cn) if get_element(r+c*1j) == '^')

start_direction = -1 + 0j

print(len(path := escape_route(grid, start_position, start_direction, return_path=True))) # part 1
print(sum(escape_route(grid, start_position, start_direction, obs) == -1 for obs in path if get_element(obs) == '.' )) # part 2
# Out:
# 4826
# 1721

# %%
correct_spots = [spot[1] for spot in zip(correct, [obs for obs in path if get_element(obs) == '.']) if spot[0] == True]

# %%
correct_spots = [(int(spot.real), int(spot.imag)) for spot in correct_spots]
correct_spots
# Out:
# [(96, 14),
#  (29, 27),
#  (103, 14),
#  (105, 14),
#  (52, 99),
#  (59, 99),
#  (30, 27),
#  (84, 99),
#  (85, 99),
#  (94, 99),
#  (96, 99),
#  (37, 107),
#  (25, 85),
#  (39, 107),
#  (29, 85),
#  (49, 85),
#  (59, 85),
#  (62, 85),
#  (71, 85),
#  (73, 85),
#  (74, 85),
#  (80, 85),
#  (85, 85),
#  (103, 85),
#  (32, 71),
#  (123, 85),
#  (44, 71),
#  (48, 71),
#  (49, 71),
#  (52, 71),
#  (59, 71),
#  (65, 71),
#  (70, 71),
#  (71, 71),
#  (81, 71),
#  (85, 71),
#  (96, 71),
#  (98, 71),
#  (103, 71),
#  (21, 57),
#  (23, 57),
#  (26, 57),
#  (32, 57),
#  (75, 107),
#  (54, 57),
#  (81, 107),
#  (71, 57),
#  (74, 57),
#  (41, 27),
#  (81, 57),
#  (4, 49),
#  (85, 57),
#  (8, 43),
#  (96, 57),
#  (98, 57),
#  (12, 43),
#  (103, 57),
#  (42, 27),
#  (107, 57),
#  (112, 57),
#  (26, 43),
#  (32, 43),
#  (52, 43),
#  (54, 43),
#  (58, 43),
#  (60, 43),
#  (70, 43),
#  (25, 27),
#  (85, 43),
#  (8, 29),
#  (8, 49),
#  (12, 29),
#  (15, 29),
#  (44, 18),
#  (26, 29),
#  (46, 27),
# ...

# %%
cause_loop = list(cause_loop)

# %%
diffs = [spot for spot in cause_loop if spot not in correct_spots]
diffs
# Out:
# [(100, 92),
#  (44, 47),
#  (45, 12),
#  (97, 58),
#  (74, 52),
#  (92, 78),
#  (88, 85),
#  (94, 100),
#  (84, 92),
#  (100, 72),
#  (104, 42),
#  (53, 117),
#  (8, 51),
#  (83, 117),
#  (103, 72),
#  (79, 101),
#  (87, 77),
#  (71, 74),
#  (19, 63),
#  (47, 79),
#  (103, 16),
#  (46, 12),
#  (84, 16),
#  (68, 7),
#  (15, 14),
#  (47, 82),
#  (97, 60),
#  (96, 78),
#  (87, 109),
#  (88, 74),
#  (84, 117),
#  (112, 35),
#  (38, 76),
#  (103, 61),
#  (83, 96),
#  (101, 62),
#  (44, 94),
#  (89, 101),
#  (40, 65),
#  (31, 16),
#  (97, 49),
#  (87, 121),
#  (100, 96),
#  (123, 79),
#  (112, 47),
#  (31, 94),
#  (100, 50),
#  (100, 63),
#  (97, 29),
#  (105, 11),
#  (44, 116),
#  (94, 94),
#  (53, 98),
#  (90, 101),
#  (12, 38),
#  (59, 91),
#  (106, 58),
#  (112, 115),
#  (44, 60),
#  (87, 58),
#  (25, 83),
#  (53, 65),
#  (53, 42),
#  (50, 9),
#  (59, 94),
#  (100, 85),
#  (47, 50),
#  (100, 98),
#  (97, 28),
#  (122, 98),
#  (100, 65),
#  (91, 101),
#  (23, 46),
#  (56, 79),
# ...

# %%
len(diffs)
# Out:
# 168

# %%
grid = []
with open("input6.txt", "r") as file:
    for line in file:
        grid.append(line)
grid = [list(row) for row in grid]

# %%
# find gaurd starting position
curr_row = 0
curr_col = 0
symbol = "^"
for row in grid:
    if symbol in row:
        curr_col = row.index(symbol)
        curr_row = grid.index(row)
        break
print("Column: ", curr_col)
print("Row: ", curr_row)
# Out:
# Column:  34
# Row:  82

# %%
gridpoint = [82,34]
horizontal_max_ind = len(grid[0])-1
vertical_max_ind = len(grid) -1

# %%
class Move:
    def __init__(self, grid):
        self.grid = grid
        self.visited = set() # To track unique spaces visited
        self.vertical_max_ind = len(grid) - 1
        self.horizontal_max_ind = len(grid[0]) - 1

        # Directions
        self.north = [-1, 0]
        self.east = [0, 1]
        self.south = [1, 0]
        self.west = [0, -1]

    def move_north(self, gridpoint):
        new_gridpoint = [x + y for x, y in zip(gridpoint, self.north)]
        print("N: ", gridpoint, new_gridpoint)
        if new_gridpoint[0] < 0:  # Out of bounds
            self.visited.add(tuple(gridpoint))
            return self.visited
        elif self.grid[new_gridpoint[0]][new_gridpoint[1]] == "#":  # Blocked
            self.visited.add(tuple(gridpoint))
            return self.move_east(gridpoint)
        else:
            self.visited.add(tuple(gridpoint))
            return self.move_north(new_gridpoint)

    def move_east(self, gridpoint):
        new_gridpoint = [x + y for x, y in zip(gridpoint, self.east)]
        print("E: ", gridpoint, new_gridpoint)
        if new_gridpoint[1] > self.horizontal_max_ind:  # Out of bounds
            self.visited.add(tuple(gridpoint))
            return self.visited
        elif self.grid[new_gridpoint[0]][new_gridpoint[1]] == "#":  # Blocked
            self.visited.add(tuple(gridpoint))
            return self.move_south(gridpoint)
        else:
            self.visited.add(tuple(gridpoint))
            return self.move_east(new_gridpoint)

    def move_south(self, gridpoint):
        new_gridpoint = [x + y for x, y in zip(gridpoint, self.south)]
        print("S: ", gridpoint, new_gridpoint)
        if new_gridpoint[0] > self.vertical_max_ind:  # Out of bounds
            self.visited.add(tuple(gridpoint))
            return self.visited
        elif self.grid[new_gridpoint[0]][new_gridpoint[1]] == "#":  # Blocked
            self.visited.add(tuple(gridpoint))
            return self.move_west(gridpoint)
        else:
            self.visited.add(tuple(gridpoint))
            return self.move_south(new_gridpoint)

    def move_west(self, gridpoint):
        new_gridpoint = [x + y for x, y in zip(gridpoint, self.west)]
        print("W: ", gridpoint, new_gridpoint)
        if new_gridpoint[1] < 0:  # Out of bounds
            self.visited.add(tuple(gridpoint))
            return self.visited
        elif self.grid[new_gridpoint[0]][new_gridpoint[1]] == "#":  # Blocked
            self.visited.add(tuple(gridpoint))
            return self.move_north(gridpoint)
        else:
            self.visited.add(tuple(gridpoint))
            return self.move_west(new_gridpoint)

# %%
import sys

sys.setrecursionlimit(200000000)  # You can set this to a higher value if needed

# %%
new_instance = Move(grid)
unique_gridpoints = new_instance.move_north(gridpoint)
print(unique_gridpoints)
# Out:
# N:  [82, 34] [81, 34]
# N:  [81, 34] [80, 34]
# N:  [80, 34] [79, 34]
# N:  [79, 34] [78, 34]
# N:  [78, 34] [77, 34]
# N:  [77, 34] [76, 34]
# N:  [76, 34] [75, 34]
# N:  [75, 34] [74, 34]
# N:  [74, 34] [73, 34]
# N:  [73, 34] [72, 34]
# N:  [72, 34] [71, 34]
# N:  [71, 34] [70, 34]
# N:  [70, 34] [69, 34]
# N:  [69, 34] [68, 34]
# N:  [68, 34] [67, 34]
# N:  [67, 34] [66, 34]
# N:  [66, 34] [65, 34]
# N:  [65, 34] [64, 34]
# N:  [64, 34] [63, 34]
# N:  [63, 34] [62, 34]
# N:  [62, 34] [61, 34]
# N:  [61, 34] [60, 34]
# N:  [60, 34] [59, 34]
# N:  [59, 34] [58, 34]
# N:  [58, 34] [57, 34]
# N:  [57, 34] [56, 34]
# N:  [56, 34] [55, 34]
# N:  [55, 34] [54, 34]
# N:  [54, 34] [53, 34]
# N:  [53, 34] [52, 34]
# N:  [52, 34] [51, 34]
# N:  [51, 34] [50, 34]
# N:  [50, 34] [49, 34]
# N:  [49, 34] [48, 34]
# N:  [48, 34] [47, 34]
# N:  [47, 34] [46, 34]
# N:  [46, 34] [45, 34]
# N:  [45, 34] [44, 34]
# N:  [44, 34] [43, 34]
# N:  [43, 34] [42, 34]
# N:  [42, 34] [41, 34]
# ...

# %%
print(len(unique_gridpoints))
# Out:
# 4826
